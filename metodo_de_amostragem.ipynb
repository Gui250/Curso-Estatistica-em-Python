# %% [markdown]
# # Amostragem Aleatória Simples

# %%
import pandas as pd 
import numpy as np 

base = pd.read_csv(
    "Datasets/analise_imoveis_sao_paulo.csv",
    sep=';',
    header=0
).drop(columns=['Unnamed: 0'])

# %%
base.head(5)
# Out:
#                               Rua               Bairro       Cidade  area_m2  \
# 0           Avenida Itacira, 255     Planalto Paulista   São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42    Jardim dos Estados   São Paulo   469-524
# 2                Rua Alba Valdez       Jardim Reimberg   São Paulo       125
# 3      Jardim Morumbi, São Paulo                    SP          NaN      310
# 4        Rua Tobias Barreto, 195                 Mooca   São Paulo       100
#
#   quartos banheiros vagas         price
# 0       4         8     6  R$ 7.000.000
# 1     3-6       3-6     4  R$ 3.700.000
# 2       4         3     2    R$ 380.000
# 3       3         2     4    R$ 685.000
# 4       3         2     2    R$ 540.000

# %%
base.shape
# Out:
# (10033, 8)

# %%
populacao = base.copy()
amostra = populacao.sample(n=100, random_state=10)
