# %% [markdown]
# ## Instalando o pandas

# %%
# %pip install pandas
# %pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Importando pacotes

# %%
import pandas as pd

# %% [markdown]
# ## Leitura de arquivos em Pandas

# %% [markdown]
# ### Arquivos CSV e TXT

# %%
df_csv = pd.read_csv("./Datasets/analise_imoveis_sao_paulo.csv", sep=";", header=0)

# %%
df_csv
# Out:
#        Unnamed: 0                             Rua               Bairro  \
# 0               0           Avenida Itacira, 255     Planalto Paulista
# 1               1  Rua Aurelia Perez Alvarez, 42    Jardim dos Estados
# 2               2                Rua Alba Valdez       Jardim Reimberg
# 3               3      Jardim Morumbi, São Paulo                    SP
# 4               4        Rua Tobias Barreto, 195                 Mooca
# ...           ...                             ...                  ...
# 10028       10028                     Rua Tapuçu            Vila Sofia
# 10029       10029                  Rua Guararema       Bosque da Saúde
# 10030       10030              Rua Estero Belaco         Vila da Saúde
# 10031       10031         Rua Manuel Onha, , 514         Vila Oratório
# 10032       10032      Rua Barão de Tramandaí, 0           Vila Alpina
#
#             Cidade  area_m2 quartos banheiros vagas  \
# 0       São Paulo      1000       4         8     6
# ...

# %% [markdown]
# ## Arquivos Excel

# %%
df_excel = pd.read_excel("./Datasets/analise_imoveis_sao_paulo.xlsx")

# %%
df_excel
# Out:
#                                   Rua               Bairro       Cidade  \
# 0               Avenida Itacira, 255     Planalto Paulista   São Paulo
# 1      Rua Aurelia Perez Alvarez, 42    Jardim dos Estados   São Paulo
# 2                    Rua Alba Valdez       Jardim Reimberg   São Paulo
# 3          Jardim Morumbi, São Paulo                    SP          NaN
# 4            Rua Tobias Barreto, 195                 Mooca   São Paulo
# ...                               ...                  ...          ...
# 10028                     Rua Tapuçu            Vila Sofia   São Paulo
# 10029                  Rua Guararema       Bosque da Saúde   São Paulo
# 10030              Rua Estero Belaco         Vila da Saúde   São Paulo
# 10031         Rua Manuel Onha, , 514         Vila Oratório   São Paulo
# 10032      Rua Barão de Tramandaí, 0           Vila Alpina   São Paulo
#
#        area_m2 quartos banheiros vagas                                 price
# ...

# %%
df_excel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10033 entries, 0 to 10032
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        10033 non-null  object
#  1   Bairro     10033 non-null  object
#  2   Cidade     6559 non-null   object
#  3   area_m2    10033 non-null  object
#  4   quartos    10033 non-null  object
#  5   banheiros  10033 non-null  object
#  6   vagas      10033 non-null  object
#  7   price      10033 non-null  object
# dtypes: object(8)
# memory usage: 627.2+ KB

# %%
df_excel[df_excel["Cidade"].isna()]
# Out:
#                                                 Rua Bairro Cidade area_m2  \
# 3                        Jardim Morumbi, São Paulo      SP    NaN     310
# 11                     Jardim Luzitânia, São Paulo      SP    NaN     436
# 33                       Parque da Lapa, São Paulo      SP    NaN     220
# 49                          Rua Artur Montenegro, 9     A     NaN     250
# 58     Chácara Santo Antônio (Zona Sul), São Paulo      SP    NaN     190
# ...                                             ...    ...    ...     ...
# 9988                  Jardim Petrópolis, São Paulo      SP    NaN     418
# 10014              Parque Alves de Lima, São Paulo      SP    NaN     122
# 10016                      Vila Formosa, São Paulo      SP    NaN     140
# 10020                     Jardim Leonor, São Paulo      SP    NaN    1345
# 10024                 Jardim Petrópolis, São Paulo      SP    NaN     418
#
#       quartos banheiros vagas         price
# ...

# %%
df_excel[df_excel["Cidade"] == "São Paulo"]
# Out:
# Empty DataFrame
# Columns: [Rua, Bairro, Cidade, area_m2, quartos, banheiros, vagas, price]
# Index: []

# %%
len(df_excel[df_excel["Cidade"].isna()]) / len(df_excel)
# Out:
# 0.3462573507425496

# %%
list(df_excel.columns)

for coluna in df_excel.columns:
    print(coluna)
# Out:
# Rua
# Bairro
# Cidade
# area_m2
# quartos
# banheiros
# vagas
# price

# %% [markdown]
# ## Temos formatações inconsistentes

# %%
df_excel.sample(n=100)
# Out:
#                                    Rua             Bairro       Cidade  \
# 1975        Rua Carlos Cyrillo Júnior       Jardim Leonor   São Paulo
# 3958               Boaçava, São Paulo                  SP          NaN
# 9981                  Rua Santo André      Vila São Pedro   São Paulo
# 4668                    Rua Gama Lobo    Vila Dom Pedro I   São Paulo
# 2294      Jardim Ana Maria, São Paulo                  SP          NaN
# ...                                ...                ...          ...
# 6321        Cidade Monções, São Paulo                  SP          NaN
# 2156  Jardim das Bandeiras, São Paulo                  SP          NaN
# 5590              Vila Ida, São Paulo                  SP          NaN
# 1184                Rua Dona Balduína              Sumaré   São Paulo
# 97                         Rua Iagari        Alto da Lapa   São Paulo
#
#      area_m2 quartos banheiros vagas         price
# 1975     900       5         5     3  R$ 6.500.000
# ...

# %%
df_excel.groupby(["Bairro", "Cidade"]).size()
# Out:
# Bairro              Cidade
#  Aclimação           São Paulo      86
#  Alto da Boa Vista   São Paulo       7
#  Alto da Lapa        São Paulo      57
#  Alto da Mooca       São Paulo      15
#  Alto de Pinheiros   São Paulo     240
#                                   ...
#  Água Rasa           São Paulo       5
# Açu                 55               1
# Brasil              10               2
#                     380              2
# Flores              74               3
# Length: 614, dtype: int64

# %%
df_duplicated = df_excel.groupby(df_excel.columns.tolist(), as_index=False).size()
df_duplicated[df_duplicated["size"] > 1]
# Out:
#                                      Rua              Bairro       Cidade  \
# 2                        Alameda Canuri    Planalto Paulista   São Paulo
# 5                        Alameda Franca      Jardim Paulista   São Paulo
# 7                   Alameda Franca, 587      Jardim Paulista   São Paulo
# 8     Alameda Gabriel Monteiro da Silva       Jardim América   São Paulo
# 9                           Alameda Itu      Jardim Paulista   São Paulo
# ...                                  ...                 ...          ...
# 4744   Travessa Roberto Douglas Machado    Jardim Paulistano   São Paulo
# 4746        Travessa Saveiros de Maroim       Vila Constança   São Paulo
# 4747          Travessa Umberto Bignardi              Paraíso   São Paulo
# 4750                           Viela Um          Jardim Peri   São Paulo
# 4753                      Viela Um, 289          Jardim Peri   São Paulo
#
#      area_m2 quartos banheiros vagas                                  price  \
# ...

# %%
columns_to_use = [column for column in df_excel.columns if column != "Unnamed: 0"]
df_excel = df_excel[columns_to_use]
df_excel
# Out:
#                                   Rua               Bairro       Cidade  \
# 0               Avenida Itacira, 255     Planalto Paulista   São Paulo
# 1      Rua Aurelia Perez Alvarez, 42    Jardim dos Estados   São Paulo
# 2                    Rua Alba Valdez       Jardim Reimberg   São Paulo
# 3          Jardim Morumbi, São Paulo                    SP          NaN
# 4            Rua Tobias Barreto, 195                 Mooca   São Paulo
# ...                               ...                  ...          ...
# 10028                     Rua Tapuçu            Vila Sofia   São Paulo
# 10029                  Rua Guararema       Bosque da Saúde   São Paulo
# 10030              Rua Estero Belaco         Vila da Saúde   São Paulo
# 10031         Rua Manuel Onha, , 514         Vila Oratório   São Paulo
# 10032      Rua Barão de Tramandaí, 0           Vila Alpina   São Paulo
#
#        area_m2 quartos banheiros vagas                                 price
# ...
